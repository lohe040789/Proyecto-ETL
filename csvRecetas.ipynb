# %%
import pandas as pd                 #bibliotecas a usar 
import numpy as np
from sqlalchemy import create_engine
import mysql.connector as conn

import warnings
warnings.filterwarnings('ignore')   # para quitar esos prints

# %%
recetas = pd.read_csv('productosyrecetas.csv') #leemos el df

# %%
recetas.head()
# Out:
#    _id  num_fila  CodRecurso  IdRecursoCategoria               Tipo  Subtipo  \
# 0    1       1.0      4995.0              5371.0  Productos típicos      NaN
# 1    2       2.0      4286.0              5369.0     Platos típicos  Segundo
# 2    3       3.0      3328.0              5319.0  Productos típicos      NaN
# 3    4       4.0      3717.0              5339.0     Platos típicos  Primero
# 4    5       5.0      3335.0              5326.0  Productos típicos      NaN
#
#   DenominacionOrigen CertificacionCalidad DIPLOMACOMPROMISO  \
# 0                  S                    N                NO
# 1                  N                    N                NO
# 2                  N                    N                NO
# 3                  N                    N                NO
# 4                  N                    N                NO
#
#    URLIdRecursoCategoria    URLNombreBuscador           URLNombreCast  \
# ...

# %%
recetas.columns #Eliminar las columnas que no nos interesan
# Out:
# Index(['_id', 'num_fila', 'CodRecurso', 'IdRecursoCategoria', 'Tipo',
#        'Subtipo', 'DenominacionOrigen', 'CertificacionCalidad',
#        'DIPLOMACOMPROMISO', 'URLIdRecursoCategoria', 'URLNombreBuscador',
#        'URLNombreCast', 'Nombre', 'Path', 'ImgFichero', 'DescripZona',
#        'DescripImpresion'],
#       dtype='object')

# %%
recetas = recetas.drop(columns=['num_fila',"CodRecurso", "IdRecursoCategoria",'Subtipo','DenominacionOrigen','CertificacionCalidad','DIPLOMACOMPROMISO','URLIdRecursoCategoria','URLNombreBuscador','URLNombreCast','Path','ImgFichero','DescripZona'])

# %%
recetas.head() #Limpiar las columnas con str fuera de lugar
# Out:
#    _id               Tipo                  Nombre  \
# 0    1  Productos típicos         Aceite de Oliva
# 1    2     Platos típicos              Ajoarriero
# 2    3  Productos típicos    Alcachofa de Navarra
# 3    4     Platos típicos  Alcachofas con almejas
# 4    5  Productos típicos                 Borraja
#
#                                     DescripImpresion
# 0  <br>Según la mitología, Atenea, diosa de la sa...
# 1  <br />Aunque Navarra no tiene mar, el bacalao ...
# 2  Amparada por la Indicación Geográfica Protegid...
# 3  <br />Este rico plato, protagonizado por una d...
# 4  <br>Procedente normalmente de las huertas de l...

# %%
recetas["DescripImpresion"] = recetas["DescripImpresion"].str.replace("<br>", "").str.replace("<br />", "").str.replace("</B>", "").str.replace("<B>", "").str.replace('</b>','').str.replace('<strong>','').str.replace('</strong>','').str.replace('<b>','')

# %%
recetas
# Out:
#     _id               Tipo                               Nombre  \
# 0     1  Productos típicos                      Aceite de Oliva
# 1     2     Platos típicos                           Ajoarriero
# 2     3  Productos típicos                 Alcachofa de Navarra
# 3     4     Platos típicos               Alcachofas con almejas
# 4     5  Productos típicos                              Borraja
# 5     6     Platos típicos                   Borraja con patata
# 6     7     Platos típicos         Canutillos rellenos de crema
# 7     8  Productos típicos                                Cardo
# 8     9     Platos típicos                   Cardo a la navarra
# 9    10  Productos típicos                                 Cava
# 10   11  Productos típicos                            Chistorra
# 11   12  Productos típicos                              Chorizo
# 12   13     Platos típicos                  Chuletón a la brasa
# 13   14  Productos típicos                   Cogollos de Tudela
# ...

# %%
recetas = recetas.drop(recetas.index[-1]) #Ultima fila eliminada por solo tener nulos

# %%
str_conn = 'mysql+pymysql://root:Reina-0601@localhost:3306/productos' # conexion a base de datos
                                                                      # conexion al servidor

# %%
cursor = create_engine(str_conn)

# %%
recetas.to_sql(name='recetas', con=cursor, if_exists='replace', index=False)
# Out:
# 43
